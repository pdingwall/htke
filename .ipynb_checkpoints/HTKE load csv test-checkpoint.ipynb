# %%
import pandas as pd
import numpy as np
import os

# %%
df1 = pd.read_csv("PD-007 - Q 1_1.csv", index_col=[0], parse_dates=[0])

# %%
df1
# Out:
#                  C:\CDSProjects\Dingwall_group\Results\PD - TEMPO\PD-007\PD-007 - Q 1.sirslt\PD-007 - Q 1.dx  \
# Data file:
# Sample name:                                           PD-007 - Q 1
# Description:                                                    NaN
# Sample amount:                                                    0
# Instrument:                                                  1100LC
# Injection date:                           2019-08-26 09:39:57+01:00
# Acq. method:                                PD - TEMPO Gradient.amx
# Analysis method:              *GC_LC Area Percent_DefaultMethod.pmx
# Last changed:                             2019-06-19 10:57:01+01:00
# Signal:                                     VWD1A,Wavelength=210 nm
# RT [min]                                                       Type
# 1.519                                                          BV
# 2.49                                                           VB
# ...

# %%
df2 = pd.read_csv("PD-007 - Q 1_1.csv")

# %%
df2
# Out:
#           Data file:  \
# 0       Sample name:
# 1       Description:
# 2     Sample amount:
# 3        Instrument:
# 4    Injection date:
# 5       Acq. method:
# 6   Analysis method:
# 7      Last changed:
# 8            Signal:
# 9           RT [min]
# 10             1.519
# 11              2.49
# 12             5.006
# 13             7.042
# 14               NaN
#
#    C:\CDSProjects\Dingwall_group\Results\PD - TEMPO\PD-007\PD-007 - Q 1.sirslt\PD-007 - Q 1.dx  \
# 0                                        PD-007 - Q 1
# 1                                                 NaN
# 2                                                   0
# 3                                              1100LC
# 4                           2019-08-26 09:39:57+01:00
# 5                             PD - TEMPO Gradient.amx
# 6               *GC_LC Area Percent_DefaultMethod.pmx
# 7                           2019-06-19 10:57:01+01:00
# 8                             VWD1A,Wavelength=210 nm
# ...

# %%
df1 = pd.read_csv("PD-007 - Q 1_1.csv", skiprows = 1,
                  index_col=[0], parse_dates=[0])
df2 = pd.read_csv("PD-007 - Q 2_1.csv", skiprows = 1,
                  index_col=[0], parse_dates=[0])
df3 = pd.read_csv("PD-007 - Q 3_1.csv", skiprows = 1,
                  index_col=[0], parse_dates=[0])

manual_raw = pd.concat([df1, df2, df3], axis=1, join='inner').sort_index()

# %%
manual_raw
# Out:
#                                            PD-007 - Q 1         Unnamed: 2  \
# Sample name:
# Acq. method:                    PD - TEMPO Gradient.amx  Injection volume:
# Analysis method:  *GC_LC Area Percent_DefaultMethod.pmx     Acq. operator:
# Description:                                        NaN                NaN
# Injection date:               2019-08-26 09:39:57+01:00         Injection:
# Instrument:                                      1100LC          Location:
# Last changed:                 2019-06-19 10:57:01+01:00                NaN
# RT [min]                                           Type        Width [min]
# Sample amount:                                        0       Sample type:
# Signal:                         VWD1A,Wavelength=210 nm                NaN
# NaN                                                 NaN                Sum
#
#                   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# Sample name:
# ...

# %%
os.chdir('C:\\Users\\padin_000\\Documents\\github\\htke\\PD-007')

dfs = [pd.read_csv(f, skiprows = 10, index_col=[0], parse_dates=[0])
        for f in os.listdir(os.getcwd()) if f.endswith('csv')]

raw_data = pd.concat(dfs)

# import os
# ...
# os.chdir('E:\\Business\\Economic Indicators')

# dfs = [pd.read_csv(f, index_col=[0], parse_dates=[0])
#         for f in os.listdir(os.getcwd()) if f.endswith('csv')]

# finaldf = pd.concat(dfs, axis=1, join='inner').sort_index()

# %%
raw_data
# Out:
#           Type Width [min]        Area     Height    Area%  Name
# RT [min]
# 1.510     BB        3.0299  55230.0460  2747.4610  96.8653   NaN
# 5.116     BB        0.8348    221.6965    11.9836   0.3888   NaN
# 7.096     BB        1.0639   1565.6123   160.8382   2.7459   NaN
# NaN        NaN         Sum  57017.3548        NaN      NaN   NaN
# 1.519     BV        1.4322  55390.1695  2745.5606  96.8723   NaN
# 2.490     VB        1.7424    239.5293     6.5397   0.4189   NaN
# 5.006     BB        0.9027   1278.9547    77.5978   2.2368   NaN
# 7.042     BB        0.4572    269.8623    28.5968   0.4720   NaN
# NaN        NaN         Sum  57178.5158        NaN      NaN   NaN
# 1.515     BB        3.1123  55654.1125  2748.0588  97.2287   NaN
# 5.038     BB        0.8639   1095.8640    63.6495   1.9145   NaN
# 7.102     BB        0.5314    490.4553    52.4376   0.8568   NaN
# NaN        NaN         Sum  57240.4318        NaN      NaN   NaN
# ...

# %%
list(raw_data)
# Out:
# ['Type',
#  'Width [min]',
#  'Area',
#  'Height',
#  'Area%',
#  'Name',
#  'Type',
#  'Width [min]',
#  'Area',
#  'Height',
#  'Area%',
#  'Name',
#  'Type',
#  'Width [min]',
#  'Area',
#  'Height',
#  'Area%',
#  'Name',
#  'Type',
#  'Width [min]',
#  'Area',
#  'Height',
#  'Area%',
#  'Name',
#  'Type',
#  'Width [min]',
#  'Area',
#  'Height',
#  'Area%',
#  'Name',
#  'Type',
#  'Width [min]',
#  'Area',
#  'Height',
#  'Area%',
#  'Name',
#  'Type',
#  'Width [min]',
#  'Area',
#  'Height',
#  'Area%',
#  'Name',
#  'Type',
#  'Width [min]',
#  'Area',
#  'Height',
#  'Area%',
#  'Name',
#  'Type',
#  'Width [min]',
#  'Area',
#  'Height',
#  'Area%',
#  'Name',
#  'Type',
#  'Width [min]',
#  'Area',
#  'Height',
#  'Area%',
#  'Name']

# %%
raw_data
# Out:
#           Type Width [min]        Area     Height    Area%  Name
# RT [min]
# 1.510     BB        3.0299  55230.0460  2747.4610  96.8653   NaN
# 5.116     BB        0.8348    221.6965    11.9836   0.3888   NaN
# 7.096     BB        1.0639   1565.6123   160.8382   2.7459   NaN
# NaN        NaN         Sum  57017.3548        NaN      NaN   NaN
# 1.519     BV        1.4322  55390.1695  2745.5606  96.8723   NaN
# 2.490     VB        1.7424    239.5293     6.5397   0.4189   NaN
# 5.006     BB        0.9027   1278.9547    77.5978   2.2368   NaN
# 7.042     BB        0.4572    269.8623    28.5968   0.4720   NaN
# NaN        NaN         Sum  57178.5158        NaN      NaN   NaN
# 1.515     BB        3.1123  55654.1125  2748.0588  97.2287   NaN
# 5.038     BB        0.8639   1095.8640    63.6495   1.9145   NaN
# 7.102     BB        0.5314    490.4553    52.4376   0.8568   NaN
# NaN        NaN         Sum  57240.4318        NaN      NaN   NaN
# ...
