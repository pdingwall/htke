# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import glob

# %%
cd PD-007/
# Out:
# C:\Users\padin_000\Documents\github\htke\PD-007

# %%
df1 = pd.read_csv("PD-007 - Q 1_1.csv", index_col=[-1], parse_dates=[0], skiprows = 10)

# %%
df1
# Out:
#      RT [min]  Type Width [min]        Area     Height    Area%
# Name
# NaN     1.519  BV        1.4322  55390.1695  2745.5606  96.8723
# NaN     2.490  VB        1.7424    239.5293     6.5397   0.4189
# NaN     5.006  BB        0.9027   1278.9547    77.5978   2.2368
# NaN     7.042  BB        0.4572    269.8623    28.5968   0.4720
# NaN       NaN   NaN         Sum  57178.5158        NaN      NaN

# %%
df2 = pd.read_csv("PD-007 - Q 1_1.csv")

# %%
df2
# Out:
#           Data file:  \
# 0       Sample name:
# 1       Description:
# 2     Sample amount:
# 3        Instrument:
# 4    Injection date:
# 5       Acq. method:
# 6   Analysis method:
# 7      Last changed:
# 8            Signal:
# 9           RT [min]
# 10             1.519
# 11              2.49
# 12             5.006
# 13             7.042
# 14               NaN
#
#    C:\CDSProjects\Dingwall_group\Results\PD - TEMPO\PD-007\PD-007 - Q 1.sirslt\PD-007 - Q 1.dx  \
# 0                                        PD-007 - Q 1
# 1                                                 NaN
# 2                                                   0
# 3                                              1100LC
# 4                           2019-08-26 09:39:57+01:00
# 5                             PD - TEMPO Gradient.amx
# 6               *GC_LC Area Percent_DefaultMethod.pmx
# 7                           2019-06-19 10:57:01+01:00
# 8                             VWD1A,Wavelength=210 nm
# 9                                                Type
# 10                                               BV
# 11                                               VB
# 12                                               BB
# 13                                               BB
# 14                                                NaN
#
#            Unnamed: 2  Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6
# 0                 NaN         NaN        NaN        NaN        NaN
# 1                 NaN         NaN        NaN        NaN        NaN
# 2        Sample type:      Sample        NaN        NaN        NaN
# 3           Location:           3        NaN        NaN        NaN
# 4          Injection:      1 of 1        NaN        NaN        NaN
# 5   Injection volume:           2        NaN        NaN        NaN
# 6      Acq. operator:      SYSTEM        NaN        NaN        NaN
# 7                 NaN         NaN        NaN        NaN        NaN
# 8                 NaN         NaN        NaN        NaN        NaN
# 9         Width [min]        Area     Height      Area%       Name
# 10             1.4322  55390.1695  2745.5606    96.8723        NaN
# 11             1.7424    239.5293     6.5397     0.4189        NaN
# 12             0.9027   1278.9547    77.5978     2.2368        NaN
# 13             0.4572    269.8623    28.5968      0.472        NaN
# 14                Sum  57178.5158        NaN        NaN        NaN

# %%
df1 = pd.read_csv("PD-007 - Q 1_1.csv", skiprows = 10,
                  index_col=[0], parse_dates=[0])
df2 = pd.read_csv("PD-007 - Q 2_1.csv", skiprows = 10,
                  index_col=[0], parse_dates=[0])
df3 = pd.read_csv("PD-007 - Q 3_1.csv", skiprows = 10,
                  index_col=[0], parse_dates=[0])

manual_raw = pd.concat([df1, df2, df3]).sort_index()

# %%
manual_raw
# Out:
#           Type Width [min]        Area     Height    Area%  Name
# RT [min]
# 1.515     BB        3.1123  55654.1125  2748.0588  97.2287   NaN
# 1.519     BV        1.4322  55390.1695  2745.5606  96.8723   NaN
# 1.522     BB        3.4963  55742.8181  2750.6365  97.0194   NaN
# 2.490     VB        1.7424    239.5293     6.5397   0.4189   NaN
# 5.006     BB        0.9027   1278.9547    77.5978   2.2368   NaN
# 5.038     BB        0.8639   1095.8640    63.6495   1.9145   NaN
# 5.130     BB        0.9124   1005.9001    55.1101   1.7508   NaN
# 7.042     BB        0.4572    269.8623    28.5968   0.4720   NaN
# 7.102     BB        0.5314    490.4553    52.4376   0.8568   NaN
# 7.120     BB        1.0268    706.6285    76.0903   1.2299   NaN
# NaN        NaN         Sum  57178.5158        NaN      NaN   NaN
# NaN        NaN         Sum  57240.4318        NaN      NaN   NaN
# NaN        NaN         Sum  57455.3468        NaN      NaN   NaN

# %%
files = os.listdir(os.getcwd())

def last_8chars(x): 
    return(x[-8:]) # defines how many characters from end of filename (includes .csv)

sorted_files = sorted(files,key = last_8chars) # sorts by character list defined above

dfs = [pd.read_csv(f, skiprows = 10, index_col=[-1])
        for f in sorted_files if f.endswith('csv')]

raw_data = pd.concat(dfs, ignore_index=True)

# import os
# ...
# os.chdir('E:\\Business\\Economic Indicators')

# dfs = [pd.read_csv(f, index_col=[0], parse_dates=[0])
#         for f in os.listdir(os.getcwd()) if f.endswith('csv')]

# finaldf = pd.concat(dfs, axis=1, join='inner').sort_index()

# %%
raw_data
# Out:
#     RT [min]  Type Width [min]        Area     Height    Area%
# 0      1.519  BV        1.4322  55390.1695  2745.5606  96.8723
# 1      2.490  VB        1.7424    239.5293     6.5397   0.4189
# 2      5.006  BB        0.9027   1278.9547    77.5978   2.2368
# 3      7.042  BB        0.4572    269.8623    28.5968   0.4720
# 4        NaN   NaN         Sum  57178.5158        NaN      NaN
# 5      1.515  BB        3.1123  55654.1125  2748.0588  97.2287
# 6      5.038  BB        0.8639   1095.8640    63.6495   1.9145
# 7      7.102  BB        0.5314    490.4553    52.4376   0.8568
# 8        NaN   NaN         Sum  57240.4318        NaN      NaN
# 9      1.522  BB        3.4963  55742.8181  2750.6365  97.0194
# 10     5.130  BB        0.9124   1005.9001    55.1101   1.7508
# 11     7.120  BB        1.0268    706.6285    76.0903   1.2299
# 12       NaN   NaN         Sum  57455.3468        NaN      NaN
# 13     1.528  BV        3.7314  56053.7556  2750.6057  97.1822
# 14     5.057  VB        0.8647    761.6352    43.3707   1.3205
# 15     7.078  BB        0.8295    863.6160    89.9067   1.4973
# 16       NaN   NaN         Sum  57679.0068        NaN      NaN
# 17     1.539  BB        3.0406  56184.1926  2750.6822  97.0353
# 18     5.080  BB        0.8590    641.7903    36.8522   1.1084
# 19     7.094  BB        0.5965   1074.8124   112.9330   1.8563
# 20       NaN   NaN         Sum  57900.7953        NaN      NaN
# 21     1.514  BB        2.9981  55434.6165  2750.1035  97.0495
# 22     4.998  BB        0.8299    497.1262    29.1159   0.8703
# 23     7.054  BB        0.8226   1188.1978   122.6763   2.0802
# 24       NaN   NaN         Sum  57119.9405        NaN      NaN
# 25     1.538  BB        3.0147  56223.5787  2749.1316  97.0656
# 26     5.095  BB        0.8251    408.5768    23.0491   0.7054
# 27     7.095  BB        1.0522   1291.1351   134.3653   2.2290
# 28       NaN   NaN         Sum  57923.2906        NaN      NaN
# 29     1.558  BB        3.0697  56819.6262  2748.9830  97.0282
# 30     5.140  BB        0.8056    329.5639    19.0625   0.5628
# 31     7.073  BB        1.0694   1410.7289   144.9031   2.4090
# 32       NaN   NaN         Sum  58559.9190        NaN      NaN
# 33     1.517  BB        3.0339  55535.9146  2747.8624  97.1077
# 34     5.058  BB        0.8105    257.4652    14.2706   0.4502
# 35     7.086  BB        0.8171   1396.6689   143.9999   2.4422
# 36       NaN   NaN         Sum  57190.0487        NaN      NaN
# 37     1.510  BB        3.0299  55230.0460  2747.4610  96.8653
# 38     5.116  BB        0.8348    221.6965    11.9836   0.3888
# 39     7.096  BB        1.0639   1565.6123   160.8382   2.7459
# 40       NaN   NaN         Sum  57017.3548        NaN      NaN

# %%
sorted_files = sorted(files)

# %%
sorted_files
# Out:
# ['PD-007 - Q 10_1.csv',
#  'PD-007 - Q 1_1.csv',
#  'PD-007 - Q 2_1.csv',
#  'PD-007 - Q 3_1.csv',
#  'PD-007 - Q 4_1.csv',
#  'PD-007 - Q 5_1.csv',
#  'PD-007 - Q 6_1.csv',
#  'PD-007 - Q 7_1.csv',
#  'PD-007 - Q 8_1.csv',
#  'PD-007 - Q 9_1.csv']

# %%
globbed_files = glob.glob("*.csv")

def last_8chars(x): 
    return(x[-8:]) # defines how many characters from end of filename (includes .csv)

sorted_glob = sorted(globbed_files,key = last_8chars) # sorts by character list defined above

data=[]
for csv in sorted_glob:
    frame = pd.read_csv(csv, skiprows = 10)
    frame['filename'] = os.path.basename(csv) # adds filename as extra column
    data.append(frame)

bigframe = pd.concat(data, ignore_index=True)

# globbed_files = glob.glob("*.csv") #creates a list of all csv files

# data=[]
# for csv in globbed_files:
#     frame = pd.read_csv(csv)
#     frame['filename'] = os.path.basename(csv)
#     data.append(frame)
    
# bigframe = pd.concat(data, ignore_index=True) #dont want pandas to try an align row indexes
# bigframe.to_csv("Pandas_output2.csv")

# %%
sorted_glob
# Out:
# ['PD-007 - Q 1_1.csv',
#  'PD-007 - Q 2_1.csv',
#  'PD-007 - Q 3_1.csv',
#  'PD-007 - Q 4_1.csv',
#  'PD-007 - Q 5_1.csv',
#  'PD-007 - Q 6_1.csv',
#  'PD-007 - Q 7_1.csv',
#  'PD-007 - Q 8_1.csv',
#  'PD-007 - Q 9_1.csv',
#  'PD-007 - Q 10_1.csv']

# %%
areas = bigframe.loc[(bigframe["RT [min]"] > 4.5) & (bigframe["RT [min]"] < 5.5)]

# %%
areas["Area"]
# Out:
# 2     1278.9547
# 6     1095.8640
# 10    1005.9001
# 14     761.6352
# 18     641.7903
# 22     497.1262
# 26     408.5768
# 30     329.5639
# 34     257.4652
# 38     221.6965
# Name: Area, dtype: float64

# %%
areas["Area"].plot(kind='line')
# Out:
# <AxesSubplot:>

# %%
areas
# Out:
#     RT [min]  Type Width [min]       Area   Height   Area%  Name  \
# 2      5.006  BB        0.9027  1278.9547  77.5978  2.2368   NaN
# 6      5.038  BB        0.8639  1095.8640  63.6495  1.9145   NaN
# 10     5.130  BB        0.9124  1005.9001  55.1101  1.7508   NaN
# 14     5.057  VB        0.8647   761.6352  43.3707  1.3205   NaN
# 18     5.080  BB        0.8590   641.7903  36.8522  1.1084   NaN
# 22     4.998  BB        0.8299   497.1262  29.1159  0.8703   NaN
# 26     5.095  BB        0.8251   408.5768  23.0491  0.7054   NaN
# 30     5.140  BB        0.8056   329.5639  19.0625  0.5628   NaN
# 34     5.058  BB        0.8105   257.4652  14.2706  0.4502   NaN
# 38     5.116  BB        0.8348   221.6965  11.9836  0.3888   NaN
#
#                filename
# 2    PD-007 - Q 1_1.csv
# 6    PD-007 - Q 2_1.csv
# 10   PD-007 - Q 3_1.csv
# 14   PD-007 - Q 4_1.csv
# 18   PD-007 - Q 5_1.csv
# 22   PD-007 - Q 6_1.csv
# 26   PD-007 - Q 7_1.csv
# 30   PD-007 - Q 8_1.csv
# 34   PD-007 - Q 9_1.csv
# 38  PD-007 - Q 10_1.csv
